# %%
# !pip install --upgrade pip
# !pip install tomotopy
# !pip install nltk
# !pip install pyvis

# %%
import pandas as pd
import tomotopy as tp

# %%
mdl = tp.CTModel.load('../data_total_longest_10000_k_28.bin')

# %% [markdown]
# # distribution

# %%
for i in range(mdl.k):
    print("topic = ",i)
    print(mdl.get_topic_words(i))
    print("--------------------------------------")
# Out:
# topic =  0
# [('scienc', 0.026964450255036354), ('www', 0.023073997348546982), ('com', 0.019404659047722816), ('sourc', 0.018528111279010773), ('org', 0.018338749185204506), ('question', 0.01828715205192566), ('paper', 0.01647430844604969), ('consid', 0.01614331267774105), ('per', 0.01582343503832817), ('link', 0.014918933622539043)]
# --------------------------------------
# topic =  1
# [('infect', 0.01901283487677574), ('immun', 0.018852822482585907), ('viru', 0.015981972217559814), ('protein', 0.015855593606829643), ('genet', 0.014367518946528435), ('diseas', 0.0142044797539711), ('respons', 0.01265749428421259), ('test', 0.01235366053879261), ('protect', 0.01193995214998722), ('gene', 0.011246944777667522)]
# --------------------------------------
# topic =  2
# ...

# %% [markdown]
# # rate

# %%
for i in range(mdl.k):
    print("topic = ",i)
    print(mdl.get_count_by_topics()[i]/mdl.get_count_by_topics().sum())
# Out:
# topic =  0
# 0.0502614699429289
# topic =  1
# 0.037999549485366844
# topic =  2
# 0.03590968186690426
# topic =  3
# 0.034899275688350294
# topic =  4
# 0.03684405631078178
# topic =  5
# 0.03693959852169713
# topic =  6
# 0.03897365435358541
# topic =  7
# 0.03564138325729174
# topic =  8
# 0.034556955514340494
# topic =  9
# 0.036801251508366745
# topic =  10
# 0.03674957830766129
# topic =  11
# 0.03777251848913237
# topic =  12
# 0.030221018222193582
# topic =  13
# 0.03439649662793936
# topic =  14
# 0.03412157628093667
# topic =  15
# 0.030998717629607205
# topic =  16
# 0.03344119276409647
# topic =  17
# 0.03565450848676155
# topic =  18
# 0.030624352976441397
# topic =  19
# 0.03340004339602897
# topic =  20
# 0.03392067749833126
# topic =  21
# 0.03353271463445349
# topic =  22
# 0.035830812244774884
# topic =  23
# 0.0399969492709881
# topic =  24
# 0.032247506354207374
# topic =  25
# 0.03367354479930519
# topic =  26
# 0.03592659094631131
# topic =  27
# ...
